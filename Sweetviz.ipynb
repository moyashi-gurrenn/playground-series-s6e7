# %%
import os
import pandas as pd
import sweetviz as sv

INPUT_DIR =  os.path.join(os.getcwd())    
print(INPUT_DIR)
train = pd.read_csv(f'{INPUT_DIR}/train.csv')

report =sv.analyze(train)
report.show_html("train_report.html")
# Out:
# /Users/yuki_ysh/Desktop/data/kaggle/playground-series-s6e7/src
# Feature: id                                  |▋         | [  6%]   00:01 -> (00:25 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: health_condition                    |█▎        | [ 12%]   00:02 -> (00:16 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# ...

# %%
df_test=pd.read_csv(os.path.join(os.getcwd(),'submission_lgb_xgb_cb.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_test=pd.read_csv(os.path.join(os.getcwd(),'submission_lgb_xgb_cb.csv'))
#
# File ~/Desktop/data/kaggle/playground-series-s6e7/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...
